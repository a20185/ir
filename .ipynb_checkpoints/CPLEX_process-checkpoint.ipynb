# %% [markdown]
# ### 需要安装CPLEX
# * [IBM CPLEX](http://www-03.ibm.com/software/products/en/ibmilogcpleoptistud)

# %%
#encoding=utf-8
# -*- coding: utf-8 -*-
# 基本部件的引用声明
import sys
import re
import codecs
import os
import shutil
import cplex
import jieba
import graphlab
import numpy as np
from array import array
from collections import Counter

# reload(sys)
# sys.setdefaultencoding('utf-8')
# Out:
# A newer version of GraphLab Create (v2.1) is available! Your current version is v2.0.1.
# You can use pip to upgrade the graphlab-create package. For more information see https://turi.com/products/create/upgrade.

# %% [markdown]
# ### 载入数据

# %%
# graphlab.load_sframe('.') 


newses = graphlab.load_sframe('./news_finished')
weibos = graphlab.load_sframe('./weibo_parsed')
# weibos_wvec = graphlab.load_sframe('./weibo_wordvec')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to ouyf5@mail2.sysu.edu.cn and will expire on November 25, 2016.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.0.1 started. Logging: C:\Users\Tidyzq\AppData\Local\Temp\graphlab_server_1469427812.log.0

# %% [markdown]
# ### 线性规划模型
# <img src="http://o9206epbs.bkt.clouddn.com/linear.png" width="300px">
#
# 其中, `Gaini(b)`, `ncnd(b)`和`Z(s)`是变量(variables), 需要cplex根据模型计算最优值

# %% [markdown]
# ### 工具函数
# * 计算bi-gram
# * 分句
# * 计算倒数和

# %%
def cal_bigram(text):
    parsed_text = [re.sub(u' |\t|　|，|；|,|、|…|“|”|"|。|！|【|】|#', '', t) for t in jieba.cut(text, cut_all = False)]
    words = [w.strip() for w in parsed_text if w.strip()]
    counter = Counter()
    for i in range(len(words) - 1):
        w = words[i] + words[i + 1]
        counter[w] = counter[w] + 1
    bidict = dict(counter)
    return bidict

def split_by_set(text):
    return re.split('。|！|【|】|#' , text)

def calc_const(weibo_bidict):
    return 1.0 / np.sum(weibo_bidict.values())

# %% [markdown]
# ### 预处理
# 将新闻和微博分句, 并计算词向量和bigram常数

# %%
# bigram_news = graphlab.SFrame()

def pre_process(news):
    sentences = split_by_set(news['text'])
    cplex_sentences = []
    cplex_bigram = Counter()
    cplex_weibo = []
    for assign_weibo in news['assign_weibos']:
        weibo = weibos.filter_by(assign_weibo['id'], 'id')
#         print weibo['text'][0]
        
        bigram = cal_bigram(weibo['text'][0])
        cplex_weibo.append({'bigram': bigram, 'const': calc_const(bigram)})
        sentences.extend(split_by_set(weibo['text'][0]))
    for sentence in sentences:
        if len(sentence):
#             parsed_text = [t + '1' for t in jieba.cut(sentence, cut_all = False)]
#             parsed_text = [re.sub(u' |\t|　|，|；|,|、|…|“|”|"|', '', t) for t in jieba.cut(sentence, cut_all = False)]
#             for text in parsed_text:
#                 print text
            bigram = cal_bigram(sentence)
            cplex_bigram = cplex_bigram + Counter(bigram)
            cplex_sentences.append({'sentence': sentence, 'bigram': bigram})
        
    return {'sentences': cplex_sentences, 'bigram': cplex_bigram, 'weibo': cplex_weibo}

# %% [markdown]
# ### 测试
# 测试以上函数正确性

# %%
news = pre_process(newses[0])
for sentence in news['sentences']:
    print "========== 句子 =========="
    print sentence['sentence']
    print "========== 词向量 =========="
    for word in sentence['bigram']:
        print word + u" 出现 " + str(sentence['bigram'][word]) + u" 次"
for weibo in news['weibo']:
    print "========== 微博 =========="
    for word in weibo['bigram']:
        print word + u" 出现 " + str(weibo['bigram'][word]) + u" 次"
    print "========== 常数 =========="
    print weibo['const']
print "========== 总词向量 =========="
for word in news['bigram']:
    print word + u" 出现 " + str(news['bigram'][word]) + u" 次"
# Out:
# ========== 句子 ==========
# 　　还有两天，2016全国高考就要开始了
# ========== 词向量 ==========
# 全国高考 出现 1 次
# 2016全国 出现 1 次
# 高考就要 出现 1 次
# 还有两天 出现 1 次
# 开始了 出现 1 次
# 两天2016 出现 1 次
# 就要开始 出现 1 次
# ========== 句子 ==========
# 　　就在考生们抓紧复习、最后冲刺时，小编也没有闲着，为学子们制作了一份高考备忘录
# ========== 词向量 ==========
# 小编也 出现 1 次
# 们抓紧 出现 1 次
# 了一份 出现 1 次
# 学子们 出现 1 次
# 一份高考 出现 1 次
# 为学子 出现 1 次
# 考生们 出现 1 次
# 时小编 出现 1 次
# 没有闲着 出现 1 次
# 抓紧复习 出现 1 次
# 在考生 出现 1 次
# 高考备忘录 出现 1 次
# 冲刺时 出现 1 次
# 复习最后 出现 1 次
# 最后冲刺 出现 1 次
# 们制作 出现 1 次
# 就在 出现 1 次
# 闲着为 出现 1 次
# 也没有 出现 1 次
# 制作了 出现 1 次
# ========== 句子 ==========
# 这里面包括考试时间、天气情况等等……如果你家里有考生，或者身边有考生，就赶快转给他们吧
# ========== 词向量 ==========
# 家里有 出现 1 次
# 等等如果 出现 1 次
# 或者身边 出现 1 次
# 就赶快 出现 1 次
# 你家里 出现 1 次
# 里面包括 出现 1 次
# 有考生 出现 2 次
# 考试时间 出现 1 次
# 时间天气情况 出现 1 次
# 身边有 出现 1 次
# 天气情况等等 出现 1 次
# 转给他们 出现 1 次
# 如果你 出现 1 次
# 他们吧 出现 1 次
# 包括考试 出现 1 次
# 考生就 出现 1 次
# 这里面 出现 1 次
# 赶快转给 出现 1 次
# 考生或者 出现 1 次
# ========== 句子 ==========
# 　　一旦在去考场的途中遇到堵车，最好的办法就是出示准考证向民警求助
# ========== 词向量 ==========
# 在去 出现 1 次
# 出示准考证 出现 1 次
# 向民警 出现 1 次
# 就是出示 出现 1 次
# 一旦在 出现 1 次
# 民警求助 出现 1 次
# 准考证向 出现 1 次
# 的办法 出现 1 次
# 的途中 出现 1 次
# 途中遇到 出现 1 次
# 遇到堵车 出现 1 次
# 去考场 出现 1 次
# 最好的 出现 1 次
# 考场的 出现 1 次
# 堵车最好 出现 1 次
# 办法就是 出现 1 次
# ========== 句子 ==========
# 但小编要说的是，防患于未然是避免问题的最好办法，这两天尽可能提前去熟悉考场周围的交通环境，要做到心中有数，以免出现意外
# ========== 词向量 ==========
# 去熟悉 出现 1 次
# 熟悉考场 出现 1 次
# 的交通 出现 1 次
# 但小编要说 出现 1 次
# 提前去 出现 1 次
# 两天尽可能 出现 1 次
# 考场周围 出现 1 次
# 是避免 出现 1 次
# 的最好 出现 1 次
# 防患于未然是 出现 1 次
# 交通环境 出现 1 次
# 的是 出现 1 次
# 要说的 出现 1 次
# 心中有数以免 出现 1 次
# 尽可能提前 出现 1 次
# 避免问题 出现 1 次
# 这两天 出现 1 次
# 环境要 出现 1 次
# 最好办法 出现 1 次
# 做到心中有数 出现 1 次
# 问题的 出现 1 次
# 是防患于未然 出现 1 次
# 办法这 出现 1 次
# 要做到 出现 1 次
# 以免出现意外 出现 1 次
# 周围的 出现 1 次
# ========== 句子 ==========
# 　　路上发现忘带准考证，如果时间宽裕，可向交警求助帮助取回
# ========== 词向量 ==========
# 向交警 出现 1 次
# 发现忘带 出现 1 次
# 准考证如果 出现 1 次
# 帮助取回 出现 1 次
# 宽裕可 出现 1 次
# 时间宽裕 出现 1 次
# 忘带准考证 出现 1 次
# 交警求助 出现 1 次
# 如果时间 出现 1 次
# 求助帮助 出现 1 次
# 路上发现 出现 1 次
# 可向 出现 1 次
# ========== 句子 ==========
# 时间紧的，要主动向监考教师说明情况，尽量协调先进场，及时给家长打电话将准考证送过来
# ========== 词向量 ==========
# 紧的 出现 1 次
# 要主动 出现 1 次
# 给家长 出现 1 次
# 主动向 出现 1 次
# 的要 出现 1 次
# 监考教师 出现 1 次
# 场及时 出现 1 次
# 协调先进 出现 1 次
# 准考证送过来 出现 1 次
# 及时给 出现 1 次
# 向监考 出现 1 次
# 时间紧 出现 1 次
# 说明情况 出现 1 次
# 打电话将 出现 1 次
# 情况尽量 出现 1 次
# 先进场 出现 1 次
# 尽量协调 出现 1 次
# 家长打电话 出现 1 次
# 将准考证 出现 1 次
# 教师说明 出现 1 次
# ========== 句子 ==========
# 　　如果考前时间宽裕，可在考点附近购买；如果已经开考了，要立即向监考老师报告，切忌相互之间自行传递
# ========== 词向量 ==========
# 老师报告 出现 1 次
# 开考了 出现 1 次
# 宽裕可 出现 1 次
# 在考点 出现 1 次
# 切忌相互之间 出现 1 次
# 了要 出现 1 次
# 附近购买 出现 1 次
# 考前时间 出现 1 次
# 立即向 出现 1 次
# 向监考 出现 1 次
# 已经开考 出现 1 次
# 可在 出现 1 次
# 要立即 出现 1 次
# 考点附近 出现 1 次
# 时间宽裕 出现 1 次
# 购买如果 出现 1 次
# 如果考前 出现 1 次
# 报告切忌 出现 1 次
# 自行传递 出现 1 次
# 监考老师 出现 1 次
# 相互之间自行 出现 1 次
# 如果已经 出现 1 次
# ========== 句子 ==========
# 　　如果考生眩晕、脸色苍白，可喝点糖水或牛奶，补充能量；或在监考人员的帮助下，选择适当的场所吸氧，或头低脚高仰卧几分钟，以保证大脑足够供血供氧
# ========== 词向量 ==========
# 吸氧或头 出现 1 次
# 补充能量 出现 1 次
# 仰卧几分钟 出现 1 次
# 可喝点 出现 1 次
# 低脚高 出现 1 次
# 高仰卧 出现 1 次
# 考生眩晕 出现 1 次
# 或头低脚 出现 1 次
# 帮助下 出现 1 次
# 监考人员 出现 1 次
# 喝点糖水 出现 1 次
# 牛奶补充 出现 1 次
# 脸色苍白可 出现 1 次
# 糖水或 出现 1 次
# 适当的 出现 1 次
# 在监考 出现 1 次
# 如果考生 出现 1 次
# 大脑足够 出现 1 次
# 的帮助 出现 1 次
# 足够供血供 出现 1 次
# 下选择 出现 1 次
# 以保证 出现 1 次
# 眩晕脸色苍白 出现 1 次
# 供血供氧 出现 1 次
# 的场所 出现 1 次
# 人员的 出现 1 次
# 几分钟以 出现 1 次
# 或在 出现 1 次
# 选择适当 出现 1 次
# 场所吸氧 出现 1 次
# 保证大脑 出现 1 次
# 能量或 出现 1 次
# 或牛奶 出现 1 次
# ========== 句子 ==========
# 家长也可给孩子置配一些常用药品，以备孩子偶有不适时调理所需
# ========== 词向量 ==========
# 药品以备 出现 1 次
# 所需 出现 1 次
# 孩子置配 出现 1 次
# 常用药品 出现 1 次
# 家长也 出现 1 次
# 偶有不 出现 1 次
# 可给 出现 1 次
# 一些常用 出现 1 次
# 不适时 出现 1 次
# 置配一些 出现 1 次
# 以备孩子 出现 1 次
# 孩子偶有 出现 1 次
# 调理所 出现 1 次
# 也可 出现 1 次
# 给孩子 出现 1 次
# 适时调理 出现 1 次
# ========== 句子 ==========
# 一般可准备以下物品：保济丸、藿香正气水、风油精等
# ========== 词向量 ==========
# 准备以下 出现 1 次
# 可准备 出现 1 次
# 一般可 出现 1 次
# 以下物品 出现 1 次
# 保济丸藿香 出现 1 次
# 物品： 出现 1 次
# 风油精等 出现 1 次
# ：保济丸 出现 1 次
# 藿香正气水 出现 1 次
# 正气水风油精 出现 1 次
# ========== 句子 ==========
# 　　遇到这样的情况，要停止答卷，学会放松
# ========== 词向量 ==========
# 遇到这样 出现 1 次
# 学会放松 出现 1 次
# 答卷学会 出现 1 次
# 情况要 出现 1 次
# 的情况 出现 1 次
# 停止答卷 出现 1 次
# 这样的 出现 1 次
# 要停止 出现 1 次
# ========== 句子 ==========
# 先闭目养神，做深呼吸，默默数数或伏案休息片刻，让大脑做短暂休息，或闭目做深呼吸3～9次，不考虑答卷上的问题；或者把笔放下、向窗外眺望，借此稳定情绪，缓解紧张心理
# ========== 词向量 ==========
# 3～ 出现 1 次
# 休息或 出现 1 次
# 深呼吸默默 出现 1 次
# 笔放下 出现 1 次
# 窗外眺望 出现 1 次
# 上的 出现 1 次
# 或者把 出现 1 次
# 眺望借此 出现 1 次
# ～9 出现 1 次
# 闭目做 出现 1 次
# 片刻让 出现 1 次
# 休息片刻 出现 1 次
# 考虑答卷 出现 1 次
# 短暂休息 出现 1 次
# 次不 出现 1 次
# 或闭目 出现 1 次
# 把笔 出现 1 次
# 大脑做 出现 1 次
# 紧张心理 出现 1 次
# 向窗外 出现 1 次
# 的问题 出现 1 次
# 做深呼吸 出现 2 次
# 放下向 出现 1 次
# 闭目养神做 出现 1 次
# 让大脑 出现 1 次
# 问题或者 出现 1 次
# 9次 出现 1 次
# 做短暂 出现 1 次
# 伏案休息 出现 1 次
# 先闭目养神 出现 1 次
# 稳定情绪缓解 出现 1 次
# 借此稳定情绪 出现 1 次
# 缓解紧张 出现 1 次
# 答卷上 出现 1 次
# 或伏案 出现 1 次
# 深呼吸3 出现 1 次
# 默默数数 出现 1 次
# 数数或 出现 1 次
# 不考虑 出现 1 次
# ========== 句子 ==========
# 　　不刻意入睡，让自己处于无意识的状态，能睡则睡，不强迫自己；可以想一些轻松的事情
# ========== 词向量 ==========
# 入睡让 出现 1 次
# 让自己 出现 1 次
# 一些轻松 出现 1 次
# 可以想 出现 1 次
# 的状态 出现 1 次
# 睡则 出现 1 次
# 的事情 出现 1 次
# 能睡 出现 1 次
# 状态能 出现 1 次
# 不刻意 出现 1 次
# 强迫自己 出现 1 次
# 无意识的 出现 1 次
# 自己可以 出现 1 次
# 则睡 出现 1 次
# 轻松的 出现 1 次
# 睡不 出现 1 次
# 自己处于 出现 1 次
# 想一些 出现 1 次
# 处于无意识 出现 1 次
# 刻意入睡 出现 1 次
# 不强迫 出现 1 次
# ========== 句子 ==========
# 有了良性的心理暗示后，情绪就会放松，入睡也就容易了
# ========== 词向量 ==========
# 心理暗示 出现 1 次
# 后情绪 出现 1 次
# 的心理 出现 1 次
# 就会 出现 1 次
# 会放松 出现 1 次
# 也就 出现 1 次
# 容易了 出现 1 次
# 暗示后 出现 1 次
# 了良性 出现 1 次
# 就容易 出现 1 次
# 入睡也 出现 1 次
# 良性的 出现 1 次
# 情绪就 出现 1 次
# 放松入睡 出现 1 次
# 有了 出现 1 次
# ========== 句子 ==========
# 如果情况特别严重，可以在医生指导下适当用药
# ========== 词向量 ==========
# 特别严重 出现 1 次
# 情况特别 出现 1 次
# 适当用药 出现 1 次
# 如果情况 出现 1 次
# 指导下 出现 1 次
# 在医生 出现 1 次
# 下适当 出现 1 次
# 严重可以 出现 1 次
# 可以在 出现 1 次
# 医生指导 出现 1 次
# ========== 句子 ==========
# 　　最后小编要为大家送上的锦囊是“平常心”
# ========== 词向量 ==========
# 是平常心 出现 1 次
# 锦囊是 出现 1 次
# 最后小 出现 1 次
# 为大家 出现 1 次
# 编要为 出现 1 次
# 小编要 出现 1 次
# 大家送上 出现 1 次
# 的锦囊 出现 1 次
# 送上的 出现 1 次
# ========== 句子 ==========
# 希望考生能够以平常心对待考试、社会能够以平常心看待高考
# ========== 词向量 ==========
# 考试社会 出现 1 次
# 希望考生 出现 1 次
# 以平常心 出现 2 次
# 考生能够 出现 1 次
# 平常心看待 出现 1 次
# 对待考试 出现 1 次
# 平常心对待 出现 1 次
# 社会能够 出现 1 次
# 看待高考 出现 1 次
# 能够以 出现 2 次
# ========== 句子 ==========
# 如果说人生是场马拉松，那么高考也许只能算是其中一公里的成绩，保持“配速”、沉着应对，才能取得最终的胜利
# ========== 词向量 ==========
# 保持配速 出现 1 次
# 高考也许 出现 1 次
# 成绩保持 出现 1 次
# 一公里 出现 1 次
# 那么高考 出现 1 次
# 场马拉松 出现 1 次
# 的胜利 出现 1 次
# 才能取得 出现 1 次
# 公里的 出现 1 次
# 是场 出现 1 次
# 人生是 出现 1 次
# 如果说人生 出现 1 次
# 算是其中 出现 1 次
# 配速沉着 出现 1 次
# 其中一 出现 1 次
# 只能算是 出现 1 次
# 沉着应对 出现 1 次
# 马拉松那么 出现 1 次
# 也许只能 出现 1 次
# 取得最终 出现 1 次
# 最终的 出现 1 次
# 的成绩 出现 1 次
# 应对才能 出现 1 次
# ========== 句子 ==========
# 只要认识到空无的道理，生命就无往而不胜
# ========== 词向量 ==========
# 无的 出现 1 次
# 到空 出现 1 次
# 只要认识 出现 1 次
# 空无 出现 1 次
# 认识到 出现 1 次
# 就无往而不胜 出现 1 次
# 生命就 出现 1 次
# 的道理 出现 1 次
# 道理生命 出现 1 次
# ========== 句子 ==========
# 生命想透了其实与一个晚期癌症病人无异，什么都不必太过执着，喜欢干点什么事就干点什么事而已
# ========== 词向量 ==========
# 太过执着 出现 1 次
# 想透了 出现 1 次
# 点什么 出现 1 次
# 什么事 出现 2 次
# 事就 出现 1 次
# 喜欢干 出现 1 次
# 与一个 出现 1 次
# 就干点 出现 1 次
# 癌症病人无异 出现 1 次
# 什么都 出现 1 次
# 不必太过 出现 1 次
# 都不必 出现 1 次
# 干点什么 出现 1 次
# 干点 出现 1 次
# 执着喜欢 出现 1 次
# 了其实 出现 1 次
# 生命想透 出现 1 次
# 事而已 出现 1 次
# 一个晚期 出现 1 次
# 其实与 出现 1 次
# 晚期癌症病人 出现 1 次
# 无异什么 出现 1 次
# ========== 句子 ==========
# “特朗普现象”其实是美国新教文明进入衰退期以后的一次自救
# ========== 词向量 ==========
# 新教文明 出现 1 次
# 美国新教 出现 1 次
# 以后的 出现 1 次
# 的一次 出现 1 次
# 一次自救 出现 1 次
# 衰退期以后 出现 1 次
# 现象其实 出现 1 次
# 进入衰退期 出现 1 次
# 是美国 出现 1 次
# 其实是 出现 1 次
# 特朗普现象 出现 1 次
# 文明进入 出现 1 次
# ========== 句子 ==========
# 特朗普和他背后的美国群众，是对内外挑战的坚决应战，是美国文明不甘沉沦的生命活力迸发
# ========== 词向量 ==========
# 应战是 出现 1 次
# 挑战的 出现 1 次
# 活力迸发 出现 1 次
# 美国文明 出现 1 次
# 生命活力 出现 1 次
# 内外挑战 出现 1 次
# 的生命 出现 1 次
# 群众是 出现 1 次
# 对内外 出现 1 次
# 和他 出现 1 次
# 特朗普和 出现 1 次
# 他背后 出现 1 次
# 文明不甘沉沦 出现 1 次
# 不甘沉沦的 出现 1 次
# 美国群众 出现 1 次
# 的坚决 出现 1 次
# 坚决应战 出现 1 次
# 是对 出现 1 次
# 是美国 出现 1 次
# 的美国 出现 1 次
# 背后的 出现 1 次
# ========== 句子 ==========
# 而与之对立的建制派，则是腐朽的、堕落的
# ========== 词向量 ==========
# 之对立 出现 1 次
# 派则 出现 1 次
# 与之 出现 1 次
# 则是 出现 1 次
# 对立的 出现 1 次
# 而与 出现 1 次
# 是腐朽 出现 1 次
# 腐朽的 出现 1 次
# 建制派 出现 1 次
# 的建制 出现 1 次
# 堕落的 出现 1 次
# 的堕落 出现 1 次
# ========== 句子 ==========
# 特朗普参选的结果，将决定美国未来是走向中兴还是就此沉沦
# ========== 词向量 ==========
# 的结果 出现 1 次
# 将决定 出现 1 次
# 是走向 出现 1 次
# 就此沉沦 出现 1 次
# 特朗普参选 出现 1 次
# 决定美国 出现 1 次
# 参选的 出现 1 次
# 美国未来 出现 1 次
# 还是就此 出现 1 次
# 中兴还是 出现 1 次
# 走向中兴 出现 1 次
# 未来是 出现 1 次
# 结果将 出现 1 次
# ========== 句子 ==========
# 中国的科技教育体制需要进一步完善，对这一点大家有广泛共识
# ========== 词向量 ==========
# 大家有 出现 1 次
# 中国的 出现 1 次
# 进一步完善 出现 1 次
# 对这 出现 1 次
# 的科技 出现 1 次
# 一点大家 出现 1 次
# 教育体制需要 出现 1 次
# 需要进一步 出现 1 次
# 有广泛 出现 1 次
# 完善对 出现 1 次
# 这一点 出现 1 次
# 广泛共识 出现 1 次
# 科技教育体制 出现 1 次
# ========== 句子 ==========
# 完善体制的重要举措之一就是支持年轻人，特别是那些独立生涯起步不久、相当于国外助理教授时期的年轻科学工作者，以及当代科学研究的主力军：博士后和研究生
# ========== 词向量 ==========
# 的重要 出现 1 次
# 生涯起步 出现 1 次
# 完善体制 出现 1 次
# 助理教授 出现 1 次
# 的年轻 出现 1 次
# 年轻人特别 出现 1 次
# 以及当代 出现 1 次
# 国外助理 出现 1 次
# 之一就是 出现 1 次
# 支持年轻人 出现 1 次
# 当代科学研究 出现 1 次
# 那些独立 出现 1 次
# 教授时期 出现 1 次
# 和研究生 出现 1 次
# 特别是 出现 1 次
# 时期的 出现 1 次
# 主力军： 出现 1 次
# 举措之一 出现 1 次
# 重要举措 出现 1 次
# 年轻科学 出现 1 次
# ：博士后 出现 1 次
# 不久相当于 出现 1 次
# 是那些 出现 1 次
# 相当于国外 出现 1 次
# 就是支持 出现 1 次
# 工作者以及 出现 1 次
# 科学研究的 出现 1 次
# 的主力军 出现 1 次
# 起步不久 出现 1 次
# 体制的 出现 1 次
# 博士后和 出现 1 次
# 科学工作者 出现 1 次
# 独立生涯 出现 1 次
# ========== 句子 ==========
# 从上个世纪80年代以来有越来越多国家的共产党与社会党开始不同程度的互相交往、联合斗争
# ========== 词向量 ==========
# 开始不同 出现 1 次
# 国家的 出现 1 次
# 多国家 出现 1 次
# 联合斗争 出现 1 次
# 有越来越 出现 1 次
# 程度的 出现 1 次
# 80年代 出现 1 次
# 以来有 出现 1 次
# 互相交往 出现 1 次
# 交往联合 出现 1 次
# 共产党与 出现 1 次
# 社会党开始 出现 1 次
# 上个世纪80 出现 1 次
# 的互相 出现 1 次
# 年代以来 出现 1 次
# 与社会党 出现 1 次
# 的共产党 出现 1 次
# 越来越多 出现 1 次
# 从上个世纪 出现 1 次
# 不同程度 出现 1 次
# ========== 句子 ==========
# 中共自1982年以来也与社会党国际和多国社会党建立联系，甚至多次派代表以观察员身份参加社会党国际每隔三年召开一次的国际代表大会
# ========== 词向量 ==========
# 召开一次 出现 1 次
# 以来也 出现 1 次
# 多次派代表 出现 1 次
# 和多国 出现 1 次
# 身份参加 出现 1 次
# 甚至多次派 出现 1 次
# 中共自 出现 1 次
# 年以来 出现 1 次
# 观察员身份 出现 1 次
# 1982年 出现 1 次
# 多国社会党 出现 1 次
# 以观察员 出现 1 次
# 的国际 出现 1 次
# 每隔三年 出现 1 次
# 社会党国际 出现 2 次
# 国际和 出现 1 次
# 国际代表大会 出现 1 次
# 国际每隔 出现 1 次
# 参加社会党 出现 1 次
# 一次的 出现 1 次
# 代表以 出现 1 次
# 三年召开 出现 1 次
# 与社会党 出现 1 次
# 社会党建立联系 出现 1 次
# 也与 出现 1 次
# 建立联系甚至 出现 1 次
# 自1982 出现 1 次
# ========== 句子 ==========
# Copyright ©1996-2016 SINA Corporation, All Rights Reserved
# ========== 词向量 ==========
# 1996- 出现 1 次
# -2016 出现 1 次
# CorporationAll 出现 1 次
# Copyright© 出现 1 次
# RightsReserved 出现 1 次
# ©1996 出现 1 次
# SINACorporation 出现 1 次
# 2016SINA 出现 1 次
# AllRights 出现 1 次
# ========== 句子 ==========
# 还有两天了
# ========== 词向量 ==========
# 还有两天 出现 1 次
# 两天了 出现 1 次
# ========== 句子 ==========
# 请收藏这份高考备忘录
# ========== 词向量 ==========
# 这份高考 出现 1 次
# 收藏这份 出现 1 次
# 请收藏 出现 1 次
# 高考备忘录 出现 1 次
# ========== 句子 ==========
# 还有两天，2016全国高考就要开始
# ========== 词向量 ==========
# 全国高考 出现 1 次
# 2016全国 出现 1 次
# 高考就要 出现 1 次
# 还有两天 出现 1 次
# 两天2016 出现 1 次
# 就要开始 出现 1 次
# ========== 句子 ==========
# 就在考生们抓紧复习、最后冲刺时，媒体专门为高考学子们制作了一份高考备忘录，包括考试时间、天气情况等等……如果你家里有考生，或者身边有考生，就赶快转给他们吧
# ========== 词向量 ==========
# 时媒体 出现 1 次
# 高考学子 出现 1 次
# 或者身边 出现 1 次
# 们制作 出现 1 次
# 一份高考 出现 1 次
# 你家里 出现 1 次
# 在考生 出现 1 次
# 备忘录包括 出现 1 次
# 有考生 出现 2 次
# 高考备忘录 出现 1 次
# 考试时间 出现 1 次
# 媒体专门 出现 1 次
# 时间天气情况 出现 1 次
# 如果你 出现 1 次
# 包括考试 出现 1 次
# 考生就 出现 1 次
# 复习最后 出现 1 次
# 赶快转给 出现 1 次
# 考生或者 出现 1 次
# 家里有 出现 1 次
# 等等如果 出现 1 次
# 就赶快 出现 1 次
# 了一份 出现 1 次
# 学子们 出现 1 次
# 专门为 出现 1 次
# 为高考 出现 1 次
# 们抓紧 出现 1 次
# 身边有 出现 1 次
# 天气情况等等 出现 1 次
# 转给他们 出现 1 次
# 考生们 出现 1 次
# 他们吧 出现 1 次
# 冲刺时 出现 1 次
# 最后冲刺 出现 1 次
# 抓紧复习 出现 1 次
# 就在 出现 1 次
# 制作了 出现 1 次
# ========== 句子 ==========
# http://t.cn/R5qYnPL @央视新闻
# ========== 词向量 ==========
# // 出现 1 次
# :/ 出现 1 次
# /R5qYnPL 出现 1 次
# @央视 出现 1 次
# t. 出现 1 次
# R5qYnPL@ 出现 1 次
# .cn 出现 1 次
# cn/ 出现 1 次
# /t 出现 1 次
# 央视新闻 出现 1 次
# http: 出现 1 次
# ========== 句子 ==========
# 广州考点今日下午开放一小时“踩点
# ========== 词向量 ==========
# 今日下午 出现 1 次
# 广州考点 出现 1 次
# 小时踩点 出现 1 次
# 一小时 出现 1 次
# 开放一 出现 1 次
# 下午开放 出现 1 次
# 考点今日 出现 1 次
# ========== 句子 ==========
# 明天,高考大幕正式拉开
# ========== 词向量 ==========
# 大幕正式 出现 1 次
# 高考大幕 出现 1 次
# 明天高考 出现 1 次
# 正式拉开 出现 1 次
# ========== 句子 ==========
# 今天下午3时至4时,广州市59个考点面向考生开放,考生可根据准考证上的考点名称和地址,提前到考点熟悉赴考路线和考试环境等
# ========== 词向量 ==========
# 环境等 出现 1 次
# 考点面向 出现 1 次
# 提前到 出现 1 次
# 名称和 出现 1 次
# 根据准考证 出现 1 次
# 个考点 出现 1 次
# 准考证上 出现 1 次
# 到考点 出现 1 次
# 时至4 出现 1 次
# 的考点 出现 1 次
# 上的 出现 1 次
# 路线和 出现 1 次
# 59个 出现 1 次
# 时广州市 出现 1 次
# 考点熟悉 出现 1 次
# 广州市59 出现 1 次
# 开放考生 出现 1 次
# 考点名称 出现 1 次
# 4时 出现 1 次
# 面向考生 出现 1 次
# 赴考路线 出现 1 次
# 考生可 出现 1 次
# 今天下午3 出现 1 次
# 可根据 出现 1 次
# 考试环境 出现 1 次
# 地址提前 出现 1 次
# 和考试 出现 1 次
# 熟悉赴考 出现 1 次
# 考生开放 出现 1 次
# 3时至 出现 1 次
# 和地址 出现 1 次
# ========== 句子 ==========
# 高考期间,考生需做好防风防雷防雨的准备,广州市招考办提醒考生,必要时可多准备一套更换的衣物,防止因天气等原因耽误考试,确保安全顺利赴考
# ========== 词向量 ==========
# 考生需 出现 1 次
# 天气等 出现 1 次
# 广州市招考办 出现 1 次
# 高考期间 出现 1 次
# 做好防风 出现 1 次
# 因天气 出现 1 次
# 原因耽误 出现 1 次
# 考生必要 出现 1 次
# 时可多准备 出现 1 次
# 必要时可多 出现 1 次
# 的准备 出现 1 次
# 等原因 出现 1 次
# 防风防雷 出现 1 次
# 考试确保安全 出现 1 次
# 防雷防雨 出现 1 次
# 耽误考试 出现 1 次
# 防雨的 出现 1 次
# 顺利赴考 出现 1 次
# 准备广州市 出现 1 次
# 的衣物 出现 1 次
# 准备一套 出现 1 次
# 招考办提醒 出现 1 次
# 需做好 出现 1 次
# 衣物防止 出现 1 次
# 期间考生 出现 1 次
# 提醒考生 出现 1 次
# 确保安全顺利 出现 1 次
# 防止因 出现 1 次
# 更换的 出现 1 次
# 一套更换 出现 1 次
# ========== 句子 ==========
# 此外,由于每个考点都安装空调,建议考生参加考试时准备一件薄外套,以备不时之需
# ========== 词向量 ==========
# 外套以备 出现 1 次
# 准备一件 出现 1 次
# 建议考生 出现 1 次
# 以备不时之需 出现 1 次
# 此外由于 出现 1 次
# 薄外套 出现 1 次
# 空调建议 出现 1 次
# 参加考试时 出现 1 次
# 一件薄 出现 1 次
# 由于每个 出现 1 次
# 安装空调 出现 1 次
# 时准备 出现 1 次
# 考点都 出现 1 次
# 考生参加考试 出现 1 次
# 都安装 出现 1 次
# 每个考点 出现 1 次
# ========== 句子 ==========
# 广州考点今日下午开放...
# ========== 词向量 ==========
# 今日下午 出现 1 次
# 广州考点 出现 1 次
# 开放... 出现 1 次
# 下午开放 出现 1 次
# 考点今日 出现 1 次
# ========== 句子 ==========
# 直播广州高考
# ========== 词向量 ==========
# 广州高考 出现 1 次
# 直播广州 出现 1 次
# ========== 句子 ==========
# 考生堵路上，电话不通拦交警求助
# ========== 词向量 ==========
# 不通拦 出现 1 次
# 考生堵 出现 1 次
# 拦交警 出现 1 次
# 交警求助 出现 1 次
# 电话不通 出现 1 次
# 堵路上 出现 1 次
# 路上电话 出现 1 次
# ========== 句子 ==========
# 44中一位张姓考生家住白云区五仙桥，今晨7点便出门和妈妈一起坐出租车前往天河中学考场，但8时32分仍堵在路上
# ========== 词向量 ==========
# 家住白云区 出现 1 次
# 32分 出现 1 次
# 今晨7 出现 1 次
# 五仙桥 出现 1 次
# 在路上 出现 1 次
# 一位张姓 出现 1 次
# 和妈妈 出现 1 次
# 仍堵 出现 1 次
# 妈妈一起 出现 1 次
# 张姓考生 出现 1 次
# 点便 出现 1 次
# 考生家住 出现 1 次
# 桥今晨 出现 1 次
# 中一位 出现 1 次
# 8时 出现 1 次
# 出门和 出现 1 次
# 7点 出现 1 次
# 坐出租车 出现 1 次
# 前往天河 出现 1 次
# 但8 出现 1 次
# 考场但 出现 1 次
# 分仍 出现 1 次
# 出租车前往 出现 1 次
# 中学考场 出现 1 次
# 一起坐 出现 1 次
# 白云区五仙 出现 1 次
# 44中 出现 1 次
# 时32 出现 1 次
# 天河中学 出现 1 次
# 便出门 出现 1 次
# 堵在 出现 1 次
# ========== 句子 ==========
# 焦急的她打电话给老师求救，“怎么办？”“找交警啊
# ========== 词向量 ==========
# 求救怎么办 出现 1 次
# ？找 出现 1 次
# 焦急的 出现 1 次
# 的她 出现 1 次
# 她打电话 出现 1 次
# 怎么办？ 出现 1 次
# 给老师 出现 1 次
# 打电话给 出现 1 次
# 交警啊 出现 1 次
# 老师求救 出现 1 次
# 找交警 出现 1 次
# ========== 句子 ==========
# ”“110打不通
# ========== 词向量 ==========
# 110打 出现 1 次
# 打不通 出现 1 次
# ========== 句子 ==========
# ”老师马上想确认该生位置，向校门前交警求助，但考生说不清楚身处位置
# ========== 词向量 ==========
# 想确认 出现 1 次
# 校门前 出现 1 次
# 考生说不清楚 出现 1 次
# 求助但 出现 1 次
# 位置向 出现 1 次
# 说不清楚身处 出现 1 次
# 身处位置 出现 1 次
# 但考生 出现 1 次
# 确认该生 出现 1 次
# 老师马上 出现 1 次
# 交警求助 出现 1 次
# 马上想 出现 1 次
# 前交警 出现 1 次
# 向校门 出现 1 次
# 该生位置 出现 1 次
# ========== 句子 ==========
# 过了一会儿，考生妈妈再度致电老师：“拦下一位交警，女儿已经在路上了
# ========== 词向量 ==========
# 拦下一位 出现 1 次
# 女儿已经 出现 1 次
# 在路上 出现 1 次
# 路上了 出现 1 次
# 过了 出现 1 次
# 考生妈妈 出现 1 次
# 再度致电 出现 1 次
# 妈妈再度 出现 1 次
# 已经在 出现 1 次
# 致电老师 出现 1 次
# 一会儿考生 出现 1 次
# 一位交警 出现 1 次
# ：拦下 出现 1 次
# 老师： 出现 1 次
# 交警女儿 出现 1 次
# 了一会儿 出现 1 次
# ========== 句子 ==========
# ”8点46分，张同学被交警摩托送到考场
# ========== 词向量 ==========
# 张同学 出现 1 次
# 8点 出现 1 次
# 点46 出现 1 次
# 被交警 出现 1 次
# 摩托送到 出现 1 次
# 同学被 出现 1 次
# 送到考场 出现 1 次
# 分张 出现 1 次
# 交警摩托 出现 1 次
# 46分 出现 1 次
# ========== 句子 ==========
# 护送她的交警几乎没作停留，马上离开赶往其他交通拥堵点
# ========== 词向量 ==========
# 赶往其他 出现 1 次
# 其他交通拥堵 出现 1 次
# 离开赶往 出现 1 次
# 她的 出现 1 次
# 停留马上 出现 1 次
# 交警几乎 出现 1 次
# 的交警 出现 1 次
# 马上离开 出现 1 次
# 几乎没作 出现 1 次
# 交通拥堵点 出现 1 次
# 护送她 出现 1 次
# 没作停留 出现 1 次
# ========== 句子 ==========
# （广州日报记者 方晴）
# ========== 词向量 ==========
# 广州日报记者 出现 1 次
# （广州日报 出现 1 次
# 记者方晴 出现 1 次
# 方晴） 出现 1 次
# ========== 句子 ==========
# 明日高考
# ========== 词向量 ==========
# 明日高考 出现 1 次
# ========== 句子 ==========
# 突发事件25个“怎么办”
# ========== 词向量 ==========
# 突发事件25 出现 1 次
# 25个 出现 1 次
# 个怎么办 出现 1 次
# ========== 句子 ==========
# ①考试前一晚失眠,不要太在乎,大脑在兴奋状态中不影响智力发挥；②如遇堵车不要急,出示准考证求助民警；③准考证丢失应立即向老师讲明情况,先考一科,后补办
# ========== 词向量 ==========
# 出示准考证 出现 1 次
# 急出示 出现 1 次
# 状态中 出现 1 次
# 在兴奋 出现 1 次
# 不影响 出现 1 次
# 准考证求助 出现 1 次
# 前一晚失眠 出现 1 次
# 不要急 出现 1 次
# 应立即向 出现 1 次
# 不要太 出现 1 次
# 民警③ 出现 1 次
# 发挥② 出现 1 次
# ②如遇 出现 1 次
# 后补办 出现 1 次
# 丢失应立即 出现 1 次
# 求助民警 出现 1 次
# 堵车不要 出现 1 次
# 失眠不要 出现 1 次
# 考试前一晚 出现 1 次
# 影响智力 出现 1 次
# 如遇堵车 出现 1 次
# 大脑在 出现 1 次
# 中不 出现 1 次
# 智力发挥 出现 1 次
# 太在乎 出现 1 次
# 讲明情况 出现 1 次
# 在乎大脑 出现 1 次
# 兴奋状态 出现 1 次
# 向老师 出现 1 次
# 先考一科 出现 1 次
# 准考证丢失 出现 1 次
# ③准考证 出现 1 次
# 老师讲明 出现 1 次
# 情况先考 出现 1 次
# 一科后 出现 1 次
# ①考试 出现 1 次
# ========== 句子 ==========
# ④每科结束后不要对题,及时放下
# ========== 词向量 ==========
# ④每 出现 1 次
# 对题及时 出现 1 次
# 不要对题 出现 1 次
# 后不要 出现 1 次
# 科结束 出现 1 次
# 及时放下 出现 1 次
# 每科 出现 1 次
# 结束后 出现 1 次
# ========== 句子 ==========
# 明天就高考了,希望学子们从容应战,排除外因,发挥出最佳水平
# ========== 词向量 ==========
# 就高考 出现 1 次
# 了希望 出现 1 次
# 发挥出 出现 1 次
# 高考了 出现 1 次
# 希望学子 出现 1 次
# 学子们 出现 1 次
# 明天就 出现 1 次
# 最佳水平 出现 1 次
# 外因发挥 出现 1 次
# 应战排除 出现 1 次
# 从容应战 出现 1 次
# 排除外因 出现 1 次
# 出最佳 出现 1 次
# 们从容 出现 1 次
# ========== 句子 ==========
# 明天高考
# ========== 词向量 ==========
# 明天高考 出现 1 次
# ========== 句子 ==========
# 突发事件25个“怎么办”
# ========== 词向量 ==========
# 突发事件25 出现 1 次
# 25个 出现 1 次
# 个怎么办 出现 1 次
# ========== 句子 ==========
# ①考试前一晚失眠，不要太在乎，大脑在兴奋状态中不影响智力发挥；②如遇堵车不要急，出示准考证求助民警；③准考证丢失应立即向老师讲明情况，先考一科，后补办
# ========== 词向量 ==========
# 出示准考证 出现 1 次
# 急出示 出现 1 次
# 状态中 出现 1 次
# 在兴奋 出现 1 次
# 不影响 出现 1 次
# 准考证求助 出现 1 次
# 前一晚失眠 出现 1 次
# 不要急 出现 1 次
# 应立即向 出现 1 次
# 不要太 出现 1 次
# 民警③ 出现 1 次
# 发挥② 出现 1 次
# ②如遇 出现 1 次
# 后补办 出现 1 次
# 丢失应立即 出现 1 次
# 求助民警 出现 1 次
# 堵车不要 出现 1 次
# 失眠不要 出现 1 次
# 考试前一晚 出现 1 次
# 影响智力 出现 1 次
# 如遇堵车 出现 1 次
# 大脑在 出现 1 次
# 中不 出现 1 次
# 智力发挥 出现 1 次
# 太在乎 出现 1 次
# 讲明情况 出现 1 次
# 在乎大脑 出现 1 次
# 兴奋状态 出现 1 次
# 向老师 出现 1 次
# 先考一科 出现 1 次
# 准考证丢失 出现 1 次
# ③准考证 出现 1 次
# 老师讲明 出现 1 次
# 情况先考 出现 1 次
# 一科后 出现 1 次
# ①考试 出现 1 次
# ========== 句子 ==========
# ④每科结束后不要对题，及时放下
# ========== 词向量 ==========
# ④每 出现 1 次
# 对题及时 出现 1 次
# 不要对题 出现 1 次
# 后不要 出现 1 次
# 科结束 出现 1 次
# 及时放下 出现 1 次
# 每科 出现 1 次
# 结束后 出现 1 次
# ========== 句子 ==========
# 明天就高考了，更多突发状况应对方案↓↓有备无患，从容应战
# ========== 词向量 ==========
# 就高考 出现 1 次
# 明天就 出现 1 次
# 高考了 出现 1 次
# 有备无患从容 出现 1 次
# ↓↓ 出现 1 次
# ↓有备无患 出现 1 次
# 应对方案 出现 1 次
# 了更 出现 1 次
# 多突发状况 出现 1 次
# 方案↓ 出现 1 次
# 更多 出现 1 次
# 从容应战 出现 1 次
# 突发状况应对 出现 1 次
# ========== 句子 ==========
# (Via人民日报)
# ========== 词向量 ==========
# Via人民日报 出现 1 次
# 人民日报) 出现 1 次
# (Via 出现 1 次
# ========== 微博 ==========
# 时媒体 出现 1 次
# 高考学子 出现 1 次
# :/ 出现 1 次
# 2016全国 出现 1 次
# 考试时间 出现 1 次
# 或者身边 出现 1 次
# 们制作 出现 1 次
# 两天了 出现 1 次
# 你家里 出现 1 次
# 就要开始 出现 1 次
# 备忘录包括 出现 1 次
# 央视新闻 出现 1 次
# 有考生 出现 2 次
# 高考备忘录 出现 2 次
# .cn 出现 1 次
# 媒体专门 出现 1 次
# 时间天气情况 出现 1 次
# 吧http 出现 1 次
# 们抓紧 出现 1 次
# 在考生 出现 1 次
# 包括考试 出现 1 次
# 考生就 出现 1 次
# 请收藏 出现 1 次
# 赶快转给 出现 1 次
# /t 出现 1 次
# 一份高考 出现 1 次
# 复习最后 出现 1 次
# 家里有 出现 1 次
# 全国高考 出现 1 次
# 等等如果 出现 1 次
# 就赶快 出现 1 次
# 了一份 出现 1 次
# 学子们 出现 1 次
# 专门为 出现 1 次
# 为高考 出现 1 次
# 收藏这份 出现 1 次
# 就在 出现 1 次
# 还有两天 出现 2 次
# @央视 出现 1 次
# 两天2016 出现 1 次
# // 出现 1 次
# 抓紧复习 出现 1 次
# 身边有 出现 1 次
# R5qYnPL@ 出现 1 次
# 天气情况等等 出现 1 次
# 备忘录还有 出现 1 次
# 了请 出现 1 次
# 如果你 出现 1 次
# 这份高考 出现 1 次
# 转给他们 出现 1 次
# 考生们 出现 1 次
# 他们吧 出现 1 次
# 考生或者 出现 1 次
# t. 出现 1 次
# 冲刺时 出现 1 次
# 开始就 出现 1 次
# 高考就要 出现 1 次
# 最后冲刺 出现 1 次
# cn/ 出现 1 次
# 制作了 出现 1 次
# /R5qYnPL 出现 1 次
# http: 出现 1 次
# ========== 常数 ==========
# 0.0153846153846
# ========== 微博 ==========
# 大幕正式 出现 1 次
# 高考大幕 出现 1 次
# 天气等 出现 1 次
# 高考期间 出现 1 次
# 做好防风 出现 1 次
# 踩点明天 出现 1 次
# 准备一件 出现 1 次
# 考生必要 出现 1 次
# 时可多准备 出现 1 次
# 广州考点 出现 2 次
# 考点都 出现 1 次
# 一小时 出现 1 次
# 路线和 出现 1 次
# 薄外套 出现 1 次
# 考点今日 出现 2 次
# 时广州市 出现 1 次
# 广州市59 出现 1 次
# 考点名称 出现 1 次
# 准备广州市 出现 1 次
# 面向考生 出现 1 次
# 必要时可多 出现 1 次
# 招考办提醒 出现 1 次
# 正式拉开 出现 1 次
# 开放一 出现 1 次
# 防雷防雨 出现 1 次
# 考生开放 出现 1 次
# 更换的 出现 1 次
# 每个考点 出现 1 次
# 根据准考证 出现 1 次
# 个考点 出现 1 次
# 的准备 出现 1 次
# 防风防雷 出现 1 次
# 熟悉赴考 出现 1 次
# 和考试 出现 1 次
# 顺利赴考 出现 1 次
# 由于每个 出现 1 次
# 安装空调 出现 1 次
# 4时 出现 1 次
# 考生可 出现 1 次
# 衣物防止 出现 1 次
# 期间考生 出现 1 次
# 原因耽误 出现 1 次
# 赴考此外 出现 1 次
# 广州市招考办 出现 1 次
# 考生需 出现 1 次
# 考点面向 出现 1 次
# 等高考 出现 1 次
# 名称和 出现 1 次
# 不时之需广州 出现 1 次
# 上的 出现 1 次
# 建议考生 出现 1 次
# 开放考生 出现 1 次
# 小时踩点 出现 1 次
# 此外由于 出现 1 次
# 提前到 出现 1 次
# 59个 出现 1 次
# 空调建议 出现 1 次
# 环境等 出现 1 次
# 耽误考试 出现 1 次
# 今日下午 出现 2 次
# 拉开今天下午 出现 1 次
# 地址提前 出现 1 次
# 赴考路线 出现 1 次
# 准备一套 出现 1 次
# 开放... 出现 1 次
# 提醒考生 出现 1 次
# 一套更换 出现 1 次
# 考试环境 出现 1 次
# 3时至 出现 1 次
# 防止因 出现 1 次
# 考点熟悉 出现 1 次
# 到考点 出现 1 次
# 时至4 出现 1 次
# 需做好 出现 1 次
# 下午开放 出现 2 次
# 因天气 出现 1 次
# 外套以备 出现 1 次
# 以备不时之需 出现 1 次
# 的考点 出现 1 次
# 准考证上 出现 1 次
# 考试确保安全 出现 1 次
# 参加考试时 出现 1 次
# 一件薄 出现 1 次
# 的衣物 出现 1 次
# 时准备 出现 1 次
# 等原因 出现 1 次
# 今天下午3 出现 1 次
# 可根据 出现 1 次
# 明天高考 出现 1 次
# 确保安全顺利 出现 1 次
# 考生参加考试 出现 1 次
# 都安装 出现 1 次
# 防雨的 出现 1 次
# 和地址 出现 1 次
# ========== 常数 ==========
# 0.0102040816327
# ========== 微博 ==========
# 一位张姓 出现 1 次
# 点便 出现 1 次
# 五仙桥 出现 1 次
# 家住白云区 出现 1 次
# 路上电话 出现 1 次
# 时32 出现 1 次
# 和妈妈 出现 1 次
# 仍堵 出现 1 次
# 过了 出现 1 次
# 考生妈妈 出现 1 次
# 8点 出现 1 次
# 再度致电 出现 1 次
# 张姓考生 出现 1 次
# 堵路上 出现 1 次
# 广州日报记者 出现 1 次
# 没作停留 出现 1 次
# 的交警 出现 1 次
# 直播广州 出现 1 次
# 已经在 出现 1 次
# 张同学 出现 1 次
# 拦交警 出现 1 次
# 了8 出现 1 次
# 老师马上 出现 1 次
# 一会儿考生 出现 1 次
# 一位交警 出现 1 次
# 身处位置 出现 1 次
# 不通老师 出现 1 次
# 但考生 出现 1 次
# 交警几乎 出现 1 次
# 怎么办？ 出现 1 次
# 向校门 出现 1 次
# 白云区五仙 出现 1 次
# 天河中学 出现 1 次
# 了一会儿 出现 1 次
# 点（ 出现 1 次
# 女儿已经 出现 1 次
# （广州日报 出现 1 次
# 路上了 出现 1 次
# 老师： 出现 1 次
# 前往天河 出现 1 次
# 给老师 出现 1 次
# 确认该生 出现 1 次
# 交警啊 出现 1 次
# 求助44 出现 1 次
# 考场但 出现 1 次
# 分仍 出现 1 次
# 7点 出现 1 次
# 位置过 出现 1 次
# 坐出租车 出现 1 次
# 致电老师 出现 1 次
# 但8 出现 1 次
# 老师求救 出现 1 次
# 离开赶往 出现 1 次
# 校门前 出现 1 次
# ：拦下 出现 1 次
# 点46 出现 1 次
# 考场护送 出现 1 次
# 堵在 出现 1 次
# 一起坐 出现 1 次
# 交警摩托 出现 1 次
# 46分 出现 1 次
# 护送她 出现 1 次
# 110打 出现 1 次
# 啊110 出现 1 次
# 想确认 出现 1 次
# 32分 出现 1 次
# 打不通 出现 1 次
# 位置向 出现 1 次
# 被交警 出现 1 次
# 说不清楚身处 出现 1 次
# 在路上 出现 2 次
# 她打电话 出现 1 次
# 今晨7 出现 1 次
# 方晴） 出现 1 次
# 桥今晨 出现 1 次
# 马上想 出现 1 次
# 交通拥堵点 出现 1 次
# 出门和 出现 1 次
# 求救怎么办 出现 1 次
# 送到考场 出现 1 次
# 记者方晴 出现 1 次
# 8时 出现 1 次
# 前交警 出现 1 次
# 她的 出现 1 次
# 停留马上 出现 1 次
# 分张 出现 1 次
# 拦下一位 出现 1 次
# 出租车前往 出现 1 次
# 考生堵 出现 1 次
# 马上离开 出现 1 次
# 路上焦急 出现 1 次
# 交警求助 出现 2 次
# 交警女儿 出现 1 次
# 高考考生 出现 1 次
# 便出门 出现 1 次
# 焦急的 出现 1 次
# 考生说不清楚 出现 1 次
# 求助但 出现 1 次
# 摩托送到 出现 1 次
# 赶往其他 出现 1 次
# 不通拦 出现 1 次
# 广州高考 出现 1 次
# 妈妈再度 出现 1 次
# 44中 出现 1 次
# 考生家住 出现 1 次
# 几乎没作 出现 1 次
# 中一位 出现 1 次
# 中学考场 出现 1 次
# ？找 出现 1 次
# 妈妈一起 出现 1 次
# 同学被 出现 1 次
# 该生位置 出现 1 次
# 打电话给 出现 1 次
# 的她 出现 1 次
# 电话不通 出现 1 次
# 其他交通拥堵 出现 1 次
# 找交警 出现 1 次
# ========== 常数 ==========
# 0.00840336134454
# ========== 微博 ==========
# 25个 出现 1 次
# 出示准考证 出现 1 次
# 准考证求助 出现 1 次
# 前一晚失眠 出现 1 次
# 丢失应立即 出现 1 次
# 突发事件25 出现 1 次
# 后补办 出现 1 次
# 们从容 出现 1 次
# ②如遇 出现 1 次
# 向老师 出现 1 次
# 情况先考 出现 1 次
# 后不要 出现 1 次
# 发挥出 出现 1 次
# 不要对题 出现 1 次
# 结束后 出现 1 次
# 如遇堵车 出现 1 次
# 外因发挥 出现 1 次
# 希望学子 出现 1 次
# 中不 出现 1 次
# 智力发挥 出现 1 次
# 怎么办① 出现 1 次
# 太在乎 出现 1 次
# 个怎么办 出现 1 次
# 在乎大脑 出现 1 次
# 及时放下 出现 1 次
# 就高考 出现 1 次
# 在兴奋 出现 1 次
# 老师讲明 出现 1 次
# 一科后 出现 1 次
# 明天就 出现 1 次
# 每科 出现 1 次
# 急出示 出现 1 次
# 状态中 出现 1 次
# 对题及时 出现 1 次
# 不影响 出现 1 次
# 不要急 出现 1 次
# 应立即向 出现 1 次
# 明日高考 出现 1 次
# 应战排除 出现 1 次
# 不要太 出现 1 次
# 民警③ 出现 1 次
# 发挥② 出现 1 次
# ④每 出现 1 次
# 最佳水平 出现 1 次
# 求助民警 出现 1 次
# 堵车不要 出现 1 次
# 高考突发事件 出现 1 次
# 失眠不要 出现 1 次
# 出最佳 出现 1 次
# 考试前一晚 出现 1 次
# 影响智力 出现 1 次
# 了希望 出现 1 次
# 排除外因 出现 1 次
# 大脑在 出现 1 次
# 学子们 出现 1 次
# 讲明情况 出现 1 次
# 从容应战 出现 1 次
# 兴奋状态 出现 1 次
# 高考了 出现 1 次
# 先考一科 出现 1 次
# 准考证丢失 出现 1 次
# ③准考证 出现 1 次
# 补办④ 出现 1 次
# 放下明天 出现 1 次
# 科结束 出现 1 次
# ①考试 出现 1 次
# ========== 常数 ==========
# 0.0151515151515
# ========== 微博 ==========
# 25个 出现 1 次
# 出示准考证 出现 1 次
# 准考证求助 出现 1 次
# 前一晚失眠 出现 1 次
# 丢失应立即 出现 1 次
# 突发事件25 出现 1 次
# ②如遇 出现 1 次
# 人民日报) 出现 1 次
# 向老师 出现 1 次
# 情况先考 出现 1 次
# 后不要 出现 1 次
# 方案↓ 出现 1 次
# 不要对题 出现 1 次
# 结束后 出现 1 次
# 如遇堵车 出现 1 次
# 中不 出现 1 次
# (Via 出现 1 次
# 智力发挥 出现 1 次
# 怎么办① 出现 1 次
# 太在乎 出现 1 次
# 个怎么办 出现 1 次
# 高考了 出现 1 次
# 在乎大脑 出现 1 次
# 及时放下 出现 1 次
# 突发状况应对 出现 1 次
# 就高考 出现 1 次
# ↓↓ 出现 1 次
# 在兴奋 出现 1 次
# 老师讲明 出现 1 次
# 一科后 出现 1 次
# 多突发状况 出现 1 次
# 明天就 出现 1 次
# 每科 出现 1 次
# 急出示 出现 1 次
# 状态中 出现 1 次
# ↓有备无患 出现 1 次
# Via人民日报 出现 1 次
# 对题及时 出现 1 次
# 不影响 出现 1 次
# 不要急 出现 1 次
# 应立即向 出现 1 次
# 不要太 出现 1 次
# 民警③ 出现 1 次
# 发挥② 出现 1 次
# ④每 出现 1 次
# 有备无患从容 出现 1 次
# 大脑在 出现 1 次
# 后补办 出现 1 次
# 求助民警 出现 1 次
# 堵车不要 出现 1 次
# 高考突发事件 出现 1 次
# 失眠不要 出现 1 次
# 考试前一晚 出现 1 次
# 影响智力 出现 1 次
# 更多 出现 1 次
# 应战( 出现 1 次
# 讲明情况 出现 1 次
# 从容应战 出现 1 次
# 兴奋状态 出现 1 次
# 了更 出现 1 次
# 先考一科 出现 1 次
# 准考证丢失 出现 1 次
# ③准考证 出现 1 次
# 应对方案 出现 1 次
# 补办④ 出现 1 次
# 明天高考 出现 1 次
# 放下明天 出现 1 次
# 科结束 出现 1 次
# ①考试 出现 1 次
# ========== 常数 ==========
# 0.0144927536232
# ========== 总词向量 ==========
# :/ 出现 1 次
# 或者身边 出现 2 次
# 高仰卧 出现 1 次
# 准备一件 出现 1 次
# 眩晕脸色苍白 出现 1 次
# 喜欢干 出现 1 次
# 张姓考生 出现 1 次
# 停留马上 出现 1 次
# 送上的 出现 1 次
# 支持年轻人 出现 1 次
# 当代科学研究 出现 1 次
# 眺望借此 出现 1 次
# 心中有数以免 出现 1 次
# 们从容 出现 1 次
# 如果说人生 出现 1 次
# 遇到堵车 出现 1 次
# 最好的 出现 1 次
# 紧的 出现 1 次
# 建制派 出现 1 次
# 是对 出现 1 次
# SINACorporation 出现 1 次
# 如果考生 出现 1 次
# 教师说明 出现 1 次
# 之对立 出现 1 次
# 了一份 出现 2 次
# 重要举措 出现 1 次
# 就会 出现 1 次
# 点便 出现 1 次
# 及时放下 出现 2 次
# 放松入睡 出现 1 次
# 准考证送过来 出现 1 次
# 为高考 出现 1 次
# 和考试 出现 1 次
# 深呼吸3 出现 1 次
# 的共产党 出现 1 次
# 在兴奋 出现 2 次
# 干点 出现 1 次
# 保济丸藿香 出现 1 次
# 和他 出现 1 次
# 只能算是 出现 1 次
# 期间考生 出现 1 次
# 就在 出现 2 次
# 每科 出现 2 次
# 人生是 出现 1 次
# 2016全国 出现 2 次
# 打不通 出现 1 次
# 低脚高 出现 1 次
# 她打电话 出现 1 次
# 时至4 出现 1 次
# 藿香正气水 出现 1 次
# 特朗普参选 出现 1 次
# 问题或者 出现 1 次
# 地址提前 出现 1 次
# 参选的 出现 1 次
# 良性的 出现 1 次
# 后补办 出现 2 次
# 主力军： 出现 1 次
# 丢失应立即 出现 2 次
# 考试环境 出现 1 次
# 路上发现 出现 1 次
# 3时至 出现 1 次
# 应对才能 出现 1 次
# 应战是 出现 1 次
# 在去 出现 1 次
# 以来也 出现 1 次
# 一起坐 出现 1 次
# 因天气 出现 1 次
# 认识到 出现 1 次
# 如果情况 出现 1 次
# 发现忘带 出现 1 次
# 多国社会党 出现 1 次
# 年轻科学 出现 1 次
# 考生家住 出现 1 次
# 附近购买 出现 1 次
# 们抓紧 出现 2 次
# 妈妈一起 出现 1 次
# 什么都 出现 1 次
# 他背后 出现 1 次
# 说明情况 出现 1 次
# 干点什么 出现 1 次
# 睡不 出现 1 次
# 适当用药 出现 1 次
# 可根据 出现 1 次
# 坚决应战 出现 1 次
# 但小编要说 出现 1 次
# 自1982 出现 1 次
# 生涯起步 出现 1 次
# 以备不时之需 出现 1 次
# 与社会党 出现 2 次
# 有越来越 出现 1 次
# 和妈妈 出现 1 次
# 准考证求助 出现 2 次
# 过了 出现 1 次
# 就无往而不胜 出现 1 次
# 考试时间 出现 2 次
# 堵路上 出现 1 次
# 不适时 出现 1 次
# 向校门 出现 1 次
# 公里的 出现 1 次
# 腐朽的 出现 1 次
# 的互相 出现 1 次
# 则是 出现 1 次
# ②如遇 出现 2 次
# 面向考生 出现 1 次
# 时期的 出现 1 次
# 怎么办？ 出现 1 次
# 适当的 出现 1 次
# 方案↓ 出现 1 次
# 交往联合 出现 1 次
# 天河中学 出现 1 次
# 科技教育体制 出现 1 次
# 没有闲着 出现 1 次
# 外因发挥 出现 1 次
# (Via 出现 1 次
# 心理暗示 出现 1 次
# 相当于国外 出现 1 次
# 以保证 出现 1 次
# 大家送上 出现 1 次
# 以后的 出现 1 次
# 的准备 出现 1 次
# 看待高考 出现 1 次
# 就高考 出现 2 次
# 是走向 出现 1 次
# 答卷上 出现 1 次
# 选择适当 出现 1 次
# 建议考生 出现 1 次
# 特别是 出现 1 次
# 衣物防止 出现 1 次
# 堵在 出现 1 次
# 路上电话 出现 1 次
# http: 出现 1 次
# 如遇堵车 出现 2 次
# 32分 出现 1 次
# 空调建议 出现 1 次
# ↓有备无患 出现 1 次
# 被交警 出现 1 次
# 家长也 出现 1 次
# 在路上 出现 2 次
# 笔放下 出现 1 次
# 明日高考 出现 1 次
# 以观察员 出现 1 次
# 媒体专门 出现 1 次
# 强迫自己 出现 1 次
# 出门和 出现 1 次
# 或闭目 出现 1 次
# 开始了 出现 1 次
# 有备无患从容 出现 1 次
# 不必太过 出现 1 次
# 和研究生 出现 1 次
# 结果将 出现 1 次
# 前交警 出现 1 次
# 她的 出现 1 次
# 分张 出现 1 次
# 忘带准考证 出现 1 次
# 出租车前往 出现 1 次
# 需要进一步 出现 1 次
# 老师求救 出现 1 次
# 防止因 出现 1 次
# 让自己 出现 1 次
# 老师报告 出现 1 次
# 要主动 出现 1 次
# 桥今晨 出现 1 次
# 大脑足够 出现 1 次
# 做短暂 出现 1 次
# 广泛共识 出现 1 次
# 不通拦 出现 1 次
# 两天尽可能 出现 1 次
# 的科技 出现 1 次
# 妈妈再度 出现 1 次
# 的考点 出现 1 次
# 特朗普现象 出现 1 次
# 道理生命 出现 1 次
# 孩子偶有 出现 1 次
# 美国群众 出现 1 次
# 的心理 出现 1 次
# 默默数数 出现 1 次
# 一个晚期 出现 1 次
# 考生参加考试 出现 1 次
# 闲着为 出现 1 次
# 独立生涯 出现 1 次
# 监考老师 出现 1 次
# 举措之一 出现 1 次
# 可喝点 出现 1 次
# 与一个 出现 1 次
# 时32 出现 1 次
# 前一晚失眠 出现 2 次
# 8点 出现 1 次
# .cn 出现 1 次
# 一旦在 出现 1 次
# 直播广州 出现 1 次
# 交通环境 出现 1 次
# 考生就 出现 2 次
# ③准考证 出现 2 次
# 牛奶补充 出现 1 次
# 中国的 出现 1 次
# 一会儿考生 出现 1 次
# 一位交警 出现 1 次
# 如果你 出现 2 次
# 考点都 出现 1 次
# 防风防雷 出现 1 次
# 交警几乎 出现 1 次
# 小编要 出现 1 次
# 处于无意识 出现 1 次
# 背后的 出现 1 次
# 将决定 出现 1 次
# 发挥出 出现 1 次
# 的问题 出现 1 次
# 平常心看待 出现 1 次
# 9次 出现 1 次
# 教育体制需要 出现 1 次
# 给家长 出现 1 次
# （广州日报 出现 1 次
# Copyright© 出现 1 次
# 确认该生 出现 1 次
# 还有两天 出现 3 次
# 在乎大脑 出现 2 次
# 考场但 出现 1 次
# 准考证如果 出现 1 次
# 抓紧复习 出现 2 次
# 顺利赴考 出现 1 次
# 由于每个 出现 1 次
# 以备孩子 出现 1 次
# 4时 出现 1 次
# 情况特别 出现 1 次
# 美国未来 出现 1 次
# 容易了 出现 1 次
# 一般可 出现 1 次
# 但8 出现 1 次
# 老师讲明 出现 2 次
# 一科后 出现 2 次
# 多突发状况 出现 1 次
# 中不 出现 2 次
# 广州市招考办 出现 1 次
# 入睡让 出现 1 次
# 考生需 出现 1 次
# 补充能量 出现 1 次
# 参加考试时 出现 1 次
# 休息或 出现 1 次
# 只要认识 出现 1 次
# 两天了 出现 1 次
# 为学子 出现 1 次
# 开始不同 出现 1 次
# 所需 出现 1 次
# 国家的 出现 1 次
# 生命就 出现 1 次
# 不要急 出现 2 次
# 在医生 出现 1 次
# 今晨7 出现 1 次
# 社会党开始 出现 1 次
# 才能取得 出现 1 次
# 或者把 出现 1 次
# 考前时间 出现 1 次
# ～9 出现 1 次
# ④每 出现 2 次
# 避免问题 出现 1 次
# 对立的 出现 1 次
# 途中遇到 出现 1 次
# 进一步完善 出现 1 次
# 的情况 出现 1 次
# 了其实 出现 1 次
# 的坚决 出现 1 次
# 也许只能 出现 1 次
# 办法这 出现 1 次
# 赶快转给 出现 2 次
# 以免出现意外 出现 1 次
# 适时调理 出现 1 次
# 不同程度 出现 1 次
# 以下物品 出现 1 次
# 影响智力 出现 2 次
# 1996- 出现 1 次
# 到考点 出现 1 次
# 提前到 出现 1 次
# -2016 出现 1 次
# 学子们 出现 3 次
# 专门为 出现 1 次
# 马上离开 出现 1 次
# 观察员身份 出现 1 次
# 足够供血供 出现 1 次
# 停止答卷 出现 1 次
# 广州高考 出现 1 次
# 进入衰退期 出现 1 次
# 交警摩托 出现 1 次
# 是避免 出现 1 次
# 的最好 出现 1 次
# 工作者以及 出现 1 次
# 防患于未然是 出现 1 次
# 周围的 出现 1 次
# 立即向 出现 1 次
# 参加社会党 出现 1 次
# 先考一科 出现 2 次
# 自己可以 出现 1 次
# 多国家 出现 1 次
# 为大家 出现 1 次
# 今天下午3 出现 1 次
# 明天高考 出现 2 次
# 科结束 出现 2 次
# 也没有 出现 1 次
# 找交警 出现 1 次
# 25个 出现 2 次
# 向交警 出现 1 次
# 们制作 出现 2 次
# 社会能够 出现 1 次
# 的要 出现 1 次
# 1982年 出现 1 次
# 考生妈妈 出现 1 次
# 的事情 出现 1 次
# 薄外套 出现 1 次
# 考点熟悉 出现 1 次
# 一次的 出现 1 次
# 教授时期 出现 1 次
# 拦交警 出现 1 次
# 能量或 出现 1 次
# 的状态 出现 1 次
# 就容易 出现 1 次
# 考点今日 出现 2 次
# 美国新教 出现 1 次
# 对题及时 出现 2 次
# 开考了 出现 1 次
# 从上个世纪 出现 1 次
# 提前去 出现 1 次
# 路上了 出现 1 次
# 考虑答卷 出现 1 次
# 给老师 出现 1 次
# 共产党与 出现 1 次
# 主动向 出现 1 次
# 2016SINA 出现 1 次
# 向老师 出现 2 次
# 7点 出现 1 次
# 缓解紧张 出现 1 次
# 安装空调 出现 1 次
# 体制的 出现 1 次
# 时间宽裕 出现 2 次
# 考生们 出现 2 次
# 他们吧 出现 2 次
# 校门前 出现 1 次
# 几乎没作 出现 1 次
# 以及当代 出现 1 次
# 自行传递 出现 1 次
# 现象其实 出现 1 次
# 则睡 出现 1 次
# 护送她 出现 1 次
# 或牛奶 出现 1 次
# 时媒体 出现 1 次
# 高考学子 出现 1 次
# 广州考点 出现 2 次
# 急出示 出现 2 次
# 对待考试 出现 1 次
# 你家里 出现 2 次
# 的年轻 出现 1 次
# 监考教师 出现 1 次
# 风油精等 出现 1 次
# 不要太 出现 2 次
# 群众是 出现 1 次
# 考场的 出现 1 次
# 片刻让 出现 1 次
# 开放考生 出现 1 次
# 及时给 出现 1 次
# 轻松的 出现 1 次
# 执着喜欢 出现 1 次
# 也可 出现 1 次
# 提醒考生 出现 1 次
# 大脑做 出现 1 次
# 求助民警 出现 2 次
# 的锦囊 出现 1 次
# 失眠不要 出现 2 次
# 考生或者 出现 2 次
# 是平常心 出现 1 次
# 焦急的 出现 1 次
# 熟悉考场 出现 1 次
# 等等如果 出现 2 次
# 求助但 出现 1 次
# 监考人员 出现 1 次
# ：博士后 出现 1 次
# 伏案休息 出现 1 次
# 了更 出现 1 次
# 结束后 出现 2 次
# 上个世纪80 出现 1 次
# 收藏这份 出现 1 次
# 中学考场 出现 1 次
# 最终的 出现 1 次
# 希望考生 出现 1 次
# 身边有 出现 2 次
# 人员的 出现 1 次
# 的途中 出现 1 次
# 帮助取回 出现 1 次
# 还是就此 出现 1 次
# 越来越多 出现 1 次
# 需做好 出现 1 次
# 这样的 出现 1 次
# 事而已 出现 1 次
# 的她 出现 1 次
# 一位张姓 出现 1 次
# 求助帮助 出现 1 次
# 把笔 出现 1 次
# 五仙桥 出现 1 次
# 高考期间 出现 1 次
# 做好防风 出现 1 次
# 会放松 出现 1 次
# 想一些 出现 1 次
# 窗外眺望 出现 1 次
# ©1996 出现 1 次
# 路线和 出现 1 次
# 这一点 出现 1 次
# 已经在 出现 1 次
# 张同学 出现 1 次
# 考点名称 出现 1 次
# 代表以 出现 1 次
# 次不 出现 1 次
# 这里面 出现 1 次
# 复习最后 出现 2 次
# 保持配速 出现 1 次
# 后不要 出现 2 次
# 老师： 出现 1 次
# 点什么 出现 1 次
# 每个考点 出现 1 次
# 了一会儿 出现 1 次
# 和多国 出现 1 次
# 脸色苍白可 出现 1 次
# 坐出租车 出现 1 次
# CorporationAll 出现 1 次
# 女儿已经 出现 1 次
# 根据准考证 出现 1 次
# 一次自救 出现 1 次
# 要做到 出现 1 次
# 派则 出现 1 次
# 状态能 出现 1 次
# 请收藏 出现 1 次
# 两天2016 出现 2 次
# 的办法 出现 1 次
# 考场周围 出现 1 次
# 的主力军 出现 1 次
# 起步不久 出现 1 次
# 都不必 出现 1 次
# 最好办法 出现 1 次
# 完善体制 出现 1 次
# 里面包括 出现 1 次
# 也就 出现 1 次
# ：拦下 出现 1 次
# 场所吸氧 出现 1 次
# 再度致电 出现 1 次
# 保证大脑 出现 1 次
# 正气水风油精 出现 1 次
# 准备以下 出现 1 次
# 活力迸发 出现 1 次
# 说不清楚身处 出现 1 次
# @央视 出现 1 次
# 了良性 出现 1 次
# 有考生 出现 4 次
# 小时踩点 出现 1 次
# 应立即向 出现 2 次
# 交通拥堵点 出现 1 次
# 的是 出现 1 次
# 记者方晴 出现 1 次
# 喝点糖水 出现 1 次
# 决定美国 出现 1 次
# 就要开始 出现 2 次
# 不甘沉沦的 出现 1 次
# 给孩子 出现 1 次
# 可以想 出现 1 次
# 下适当 出现 1 次
# 便出门 出现 1 次
# 考试社会 出现 1 次
# 让大脑 出现 1 次
# 大脑在 出现 2 次
# 甚至多次派 出现 1 次
# 答卷学会 出现 1 次
# 美国文明 出现 1 次
# 遇到这样 出现 1 次
# 80年代 出现 1 次
# 能睡 出现 1 次
# 可给 出现 1 次
# 的建制 出现 1 次
# 国际和 出现 1 次
# 兴奋状态 出现 2 次
# 医生指导 出现 1 次
# 46分 出现 1 次
# 已经开考 出现 1 次
# 文明不甘沉沦 出现 1 次
# 时准备 出现 1 次
# 调理所 出现 1 次
# 去考场 出现 1 次
# 耽误考试 出现 1 次
# 短暂休息 出现 1 次
# 尽量协调 出现 1 次
# 是场 出现 1 次
# 年代以来 出现 1 次
# 睡则 出现 1 次
# 就是支持 出现 1 次
# 都安装 出现 1 次
# 不考虑 出现 1 次
# 电话不通 出现 1 次
# 的生命 出现 1 次
# 年以来 出现 1 次
# 生命活力 出现 1 次
# 在考生 出现 2 次
# 仍堵 出现 1 次
# 宽裕可 出现 2 次
# 以平常心 出现 2 次
# 其中一 出现 1 次
# 就干点 出现 1 次
# 招考办提醒 出现 1 次
# 的胜利 出现 1 次
# 一套更换 出现 1 次
# 的一次 出现 1 次
# 报告切忌 出现 1 次
# 打电话将 出现 1 次
# 人民日报) 出现 1 次
# 情况要 出现 1 次
# 是防患于未然 出现 1 次
# 指导下 出现 1 次
# 有广泛 出现 1 次
# 糖水或 出现 1 次
# ↓↓ 出现 1 次
# 在监考 出现 1 次
# 晚期癌症病人 出现 1 次
# 做深呼吸 出现 2 次
# 药品以备 出现 1 次
# 可在 出现 1 次
# 的结果 出现 1 次
# 多次派代表 出现 1 次
# 休息片刻 出现 1 次
# ？找 出现 1 次
# 常用药品 出现 1 次
# 一点大家 出现 1 次
# 开放一 出现 1 次
# 其实是 出现 1 次
# 有了 出现 1 次
# 向监考 出现 2 次
# 就此沉沦 出现 1 次
# 环境要 出现 1 次
# 考点附近 出现 1 次
# 的衣物 出现 1 次
# 分仍 出现 1 次
# 暗示后 出现 1 次
# 到空 出现 1 次
# 时间天气情况 出现 2 次
# 最后冲刺 出现 2 次
# 是美国 出现 2 次
# 刻意入睡 出现 1 次
# 其实与 出现 1 次
# 不强迫 出现 1 次
# 的重要 出现 1 次
# 考点面向 出现 1 次
# 锦囊是 出现 1 次
# 高考也许 出现 1 次
# 深呼吸默默 出现 1 次
# Via人民日报 出现 1 次
# 不影响 出现 2 次
# 了要 出现 1 次
# 时小编 出现 1 次
# 应战排除 出现 1 次
# 国际每隔 出现 1 次
# 以来有 出现 1 次
# 等原因 出现 1 次
# 今日下午 出现 2 次
# 三年召开 出现 1 次
# 学会放松 出现 1 次
# t. 出现 1 次
# 赴考路线 出现 1 次
# 数数或 出现 1 次
# 开放... 出现 1 次
# 算是其中 出现 1 次
# 情况尽量 出现 1 次
# 家长打电话 出现 1 次
# 考生说不清楚 出现 1 次
# 民警③ 出现 2 次
# /t 出现 1 次
# 交警女儿 出现 1 次
# 考试前一晚 出现 2 次
# 确保安全顺利 出现 1 次
# 求救怎么办 出现 1 次
# 全国高考 出现 2 次
# 环境等 出现 1 次
# 闭目养神做 出现 1 次
# 一份高考 出现 2 次
# 高考就要 出现 2 次
# 癌症病人无异 出现 1 次
# 下午开放 出现 2 次
# 外套以备 出现 1 次
# 下选择 出现 1 次
# 的国际 出现 1 次
# 如果时间 出现 1 次
# 供血供氧 出现 1 次
# // 出现 1 次
# 前往天河 出现 1 次
# 一件薄 出现 1 次
# 或在 出现 1 次
# 送到考场 出现 1 次
# 购买如果 出现 1 次
# 应对方案 出现 1 次
# AllRights 出现 1 次
# ①考试 出现 2 次
# 吸氧或头 出现 1 次
# 挑战的 出现 1 次
# 家住白云区 出现 1 次
# 生命想透 出现 1 次
# 的道理 出现 1 次
# 就是出示 出现 1 次
# 场马拉松 出现 1 次
# 一小时 出现 1 次
# 广州日报记者 出现 1 次
# 社会党建立联系 出现 1 次
# 国外助理 出现 1 次
# 可向 出现 1 次
# 那些独立 出现 1 次
# 的堕落 出现 1 次
# 是腐朽 出现 1 次
# 联合斗争 出现 1 次
# 必要时可多 出现 1 次
# 包括考试 出现 2 次
# 沉着应对 出现 1 次
# 的帮助 出现 1 次
# 白云区五仙 出现 1 次
# 熟悉赴考 出现 1 次
# 的成绩 出现 1 次
# 借此稳定情绪 出现 1 次
# 的美国 出现 1 次
# 向民警 出现 1 次
# 准考证上 出现 1 次
# 就赶快 出现 2 次
# 智力发挥 出现 2 次
# 致电老师 出现 1 次
# 也与 出现 1 次
# 个怎么办 出现 2 次
# 每隔三年 出现 1 次
# 交警啊 出现 1 次
# 场及时 出现 1 次
# 国际代表大会 出现 1 次
# 防雷防雨 出现 1 次
# 无意识的 出现 1 次
# 要说的 出现 1 次
# R5qYnPL@ 出现 1 次
# 天气情况等等 出现 2 次
# 配速沉着 出现 1 次
# 小编也 出现 1 次
# 考生可 出现 1 次
# 取得最终 出现 1 次
# 原因耽误 出现 1 次
# 科学工作者 出现 1 次
# 社会党国际 出现 2 次
# 走向中兴 出现 1 次
# /R5qYnPL 出现 1 次
# 制作了 出现 2 次
# 家里有 出现 2 次
# 想确认 出现 1 次
# 转给他们 出现 2 次
# 孩子置配 出现 1 次
# 助理教授 出现 1 次
# 位置向 出现 1 次
# 名称和 出现 1 次
# 切忌相互之间 出现 1 次
# 稳定情绪缓解 出现 1 次
# 什么事 出现 2 次
# 此外由于 出现 1 次
# 排除外因 出现 1 次
# 马上想 出现 1 次
# 59个 出现 1 次
# 的交通 出现 1 次
# 置配一些 出现 1 次
# 先闭目养神 出现 1 次
# 最后小 出现 1 次
# 问题的 出现 1 次
# 时广州市 出现 1 次
# 拦下一位 出现 1 次
# 之一就是 出现 1 次
# 马拉松那么 出现 1 次
# 堵车不要 出现 2 次
# 建立联系甚至 出现 1 次
# 完善对 出现 1 次
# 该生位置 出现 1 次
# 召开一次 出现 1 次
# 了希望 出现 1 次
# 大家有 出现 1 次
# 更多 出现 1 次
# 身处位置 出现 1 次
# 对这 出现 1 次
# 中共自 出现 1 次
# 不要对题 出现 2 次
# 事就 出现 1 次
# 摩托送到 出现 1 次
# 44中 出现 1 次
# 民警求助 出现 1 次
# 情绪就 出现 1 次
# 新教文明 出现 1 次
# 可准备 出现 1 次
# 太过执着 出现 1 次
# 与之 出现 1 次
# 高考了 出现 2 次
# 几分钟以 出现 1 次
# 中兴还是 出现 1 次
# 放下向 出现 1 次
# 博士后和 出现 1 次
# 或伏案 出现 1 次
# 高考备忘录 出现 3 次
# 冲刺时 出现 2 次
# 那么高考 出现 1 次
# 堵车最好 出现 1 次
# cn/ 出现 1 次
# 防雨的 出现 1 次
# 和地址 出现 1 次
# 大幕正式 出现 1 次
# 高考大幕 出现 1 次
# 天气等 出现 1 次
# 考生堵 出现 1 次
# 空无 出现 1 次
# 特别严重 出现 1 次
# RightsReserved 出现 1 次
# 考生必要 出现 1 次
# 时可多准备 出现 1 次
# 年轻人特别 出现 1 次
# 110打 出现 1 次
# 一些常用 出现 1 次
# 上的 出现 2 次
# 编要为 出现 1 次
# 能够以 出现 2 次
# 对内外 出现 1 次
# 闭目做 出现 1 次
# 从容应战 出现 2 次
# 考生能够 出现 1 次
# 这两天 出现 1 次
# 而与 出现 1 次
# 老师马上 出现 1 次
# 其他交通拥堵 出现 1 次
# 状态中 出现 2 次
# 自己处于 出现 1 次
# 衰退期以后 出现 1 次
# 情况先考 出现 2 次
# 物品： 出现 1 次
# 向窗外 出现 1 次
# 更换的 出现 1 次
# 无异什么 出现 1 次
# 堕落的 出现 1 次
# 但考生 出现 1 次
# 一些轻松 出现 1 次
# 希望学子 出现 1 次
# 想透了 出现 1 次
# 太在乎 出现 2 次
# 是那些 出现 1 次
# 的交警 出现 1 次
# 后情绪 出现 1 次
# 8时 出现 1 次
# 准备广州市 出现 1 次
# 突发状况应对 出现 1 次
# 考生眩晕 出现 1 次
# 时间紧 出现 1 次
# 做到心中有数 出现 1 次
# 的场所 出现 1 次
# 考生开放 出现 1 次
# 离开赶往 出现 1 次
# 程度的 出现 1 次
# 如果考前 出现 1 次
# 在考点 出现 1 次
# 入睡也 出现 1 次
# 将准考证 出现 1 次
# 严重可以 出现 1 次
# 明天就 出现 2 次
# 要停止 出现 1 次
# 正式拉开 出现 1 次
# 文明进入 出现 1 次
# 仰卧几分钟 出现 1 次
# 央视新闻 出现 1 次
# 3～ 出现 1 次
# 特朗普和 出现 1 次
# 广州市59 出现 1 次
# 方晴） 出现 1 次
# 个考点 出现 1 次
# 偶有不 出现 1 次
# 备忘录包括 出现 1 次
# 办法就是 出现 1 次
# 内外挑战 出现 1 次
# 可以在 出现 1 次
# 互相交往 出现 1 次
# 或头低脚 出现 1 次
# 协调先进 出现 1 次
# 不刻意 出现 1 次
# 点46 出现 1 次
# 发挥② 出现 2 次
# 帮助下 出现 1 次
# 赶往其他 出现 1 次
# 尽可能提前 出现 1 次
# 准备一套 出现 1 次
# 最佳水平 出现 1 次
# 紧张心理 出现 1 次
# 交警求助 出现 3 次
# 出最佳 出现 1 次
# 相互之间自行 出现 1 次
# 未来是 出现 1 次
# 没作停留 出现 1 次
# 去熟悉 出现 1 次
# 准考证向 出现 1 次
# 身份参加 出现 1 次
# 成绩保持 出现 1 次
# 平常心对待 出现 1 次
# 不久相当于 出现 1 次
# 出示准考证 出现 3 次
# 讲明情况 出现 2 次
# ：保济丸 出现 1 次
# 中一位 出现 1 次
# 要立即 出现 1 次
# 考试确保安全 出现 1 次
# 科学研究的 出现 1 次
# 突发事件25 出现 2 次
# 准考证丢失 出现 2 次
# 这份高考 出现 1 次
# 同学被 出现 1 次
# 先进场 出现 1 次
# 无的 出现 1 次
# 一公里 出现 1 次
# 打电话给 出现 1 次
# 如果已经 出现 1 次

# %%
def solve_cplex(prob):

    prob.solve()

    numrows = prob.linear_constraints.get_num()
    numcols = prob.variables.get_num()

    print
    # solution.get_status() returns an integer code
    print "Solution status = " , prob.solution.get_status(), ":",
    # the following line prints the corresponding string
    print prob.solution.status[prob.solution.get_status()]
    print "Solution value  = ", prob.solution.get_objective_value()
    slack = prob.solution.get_linear_slacks()
    pi    = prob.solution.get_dual_values()
    x     = prob.solution.get_values()
    dj    = prob.solution.get_reduced_costs()
    for i in range(numrows):
        print "Row %d:  Slack = %10f  Pi = %10f" % (i, slack[i], pi[i])
    for j in range(numcols):
        print "Column %d:  Value = %10f Reduced cost = %10f" % (j, x[j], dj[j])

# %%
max_L = 1000 # 选取句子的最大长度

def cplex_process(news):
    c = cplex.Cplex()
    c.objective.set_sense(c.objective.sense.maximize)
    
    num_b = len(news['bigram'])
    print 'size of b: %d' % num_b
    num_i = len(news['weibo'])
    print 'size of i: %d' % num_i
    num_s = len(news['sentences'])
    print 'size of s: %d' % num_s
    
#     z_vec = [0] * num_s
    z_type = [c.variables.type.integer] * num_s
    z_name = ['z_' + str(s) for s in range(num_s)]
    z_ub = [1] * num_s
    z_lb = [0] * num_s
    
#     gain_mat = [0] * num_i * num_b
    gain_type = [c.variables.type.integer] * num_i * num_b
    gain_name = ['gain_' + str(i) + '_' + str(b) for i in range(num_i) for b in range(num_b)]
    gain_ub = [news['weibo'][i]['bigram'][news['bigram'].keys()[b]] for i in range(num_i) for b in range(num_b)] # Gain < Ntwt
    gain_lb = [0] * num_i * num_b
    gain_obj = [news['weibo'][i]['const'] for i in range(num_i) for b in range(num_b)] # 目标函数, 取最大值
    
    c.variables.add(ub = z_ub, lb = z_lb, names = z_name, types = z_type)
    c.variables.add(obj = gain_obj, ub = gain_ub, lb = gain_lb, names = gain_name, types = gain_type)
    
    c1_rows = [] # Gain < Ncnd
    for b in range(num_b):
        for i in range(num_i):
            names = ['gain_' + str(i) + '_' + str(b)]
            values = [1.0]
            for s in range(num_s):
                names.append('z_' + str(s))
                values.append(-1 * news['sentences'][s]['bigram'][news['bigram'].keys()[b]])
            c1_rows.append([names, values])
    c1_senses = 'L' * num_i * num_b
    c1_rhs = [0.0] * num_i * num_b
    
    c2_rows = [[['z_' + str(s) for s in range(num_s)], [len(weibo['sentences'][s]['sentence']) for s in range(num_s)]]] # sum(Z(s) * length(s)) < L
    c2_senses = 'L'
    c2_rhs = max_L
    
    c.linear_constraints.add(lin_expr = c1_rows, senses = c1_senses, rhs = c1_rhs)
    c.linear_constraints.add(lin_expr = c2_rows, senses = c2_senses, rhs = c2_rhs)
    
    solve_cplex(c)

# %% [markdown]
# ### 测试

# %%
news = pre_process(newses[0])
cplex_process(news)
# Out:
# size of b: 810
# size of i: 5
# size of s: 62
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-17d803263e92> in <module>()
#       1 news = pre_process(newses[0])
# ----> 2 cplex_process(news)
#
# <ipython-input-95-670617b71c8d> in cplex_process(news)
#      21     gain_type = [c.variables.type.integer] * num_i * num_b
#      22     gain_name = ['gain_' + str(i) + '_' + str(b) for i in range(num_i) for b in range(num_b)]
# ---> 23     gain_ub = [news['weibo'][i]['bigram'][news['bigram'][b]] for i in range(num_i) for b in range(num_b)] # Gain < Ntwt
#      24     gain_lb = [0] * num_i * num_b
#      25     gain_obj = [news['weibo'][i]['const'] for i in range(num_i) for b in range(num_b)] # 目标函数, 取最大值
#
# KeyError: 0

# %% [markdown]
# ### 测试

# %%
cplex_process(0)
# Out:
# [{'id': 3982762123284430L, 'similarity': 745.781477009773},
#  {'id': 3983296700071844L, 'similarity': 709.2981882328462},
#  {'id': 3984021052670259L, 'similarity': 582.361230574927},
#  {'id': 3983485443515171L, 'similarity': 578.9552991144867},
#  {'id': 3983330271457947L, 'similarity': 560.7869467061566}]
